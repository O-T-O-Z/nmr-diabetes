# %%
from utils import load_best_features
import pandas as pd
import os
import sys

sys.path.append("../../src")

DATA_FOLDER = "../datasets.nosync/"

clinical_df = pd.read_csv(os.path.join(DATA_FOLDER, "clinical_train.csv"))
features = load_best_features("../results_fs/clinical_best_features.txt")

# %%
from visualization import plot_difference, plot_multiple_spectra
from utils import load_best_features
import pandas as pd
import os
import sys

sys.path.append("../../src")

DATA_FOLDER = "../datasets.nosync/"

nmr_df = pd.read_csv(os.path.join(DATA_FOLDER, "nmr_train.csv"))
features = load_best_features("../results_fs/nmr_best_features.txt")
plot_multiple_spectra(nmr_df)
plot_difference(nmr_df)
plot_difference(nmr_df, features=features)

# %%
from visualization import plot_cumulative_variance

plot_cumulative_variance()

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
all_results = {}
results_folder = "../results_models/baselines/"

for f in os.listdir(results_folder):
    if f.endswith(".csv"):
        dataset = f.split(".csv")[0].split("_baseline_results")[0].title()

        all_results[dataset] = pd.read_csv(f"{results_folder}/{f}").drop(columns=["Unnamed: 0"])
        all_results[dataset]["Dataset"] = dataset

for f in os.listdir("../results_models/deepsurv/"):
    if f.endswith(".csv"):
        dataset = f.split(".csv")[0].split("_deepsurv_results")[0].title()
        deepsurv = pd.read_csv(f"../results_models/deepsurv/{f}").drop(columns=["Unnamed: 0"])[["DeepSurv"]]
        all_results[dataset] = pd.concat([all_results[dataset], deepsurv], axis=1)

for f in os.listdir("../results_models/xgb-aft/bagging2024-06-26_11-54-15/"):
    if f.endswith(".csv") and "test_results" in f:
        dataset = f.split(".csv")[0].split("test_results_")[-1].title()
        xgb = pd.read_csv(
            f"../results_models/xgb-aft/bagging2024-06-26_11-54-15/{f}"
        ).drop(columns=["Unnamed: 0"])[["C-index"]]
        xgb.rename(columns={"C-index": "XGBoost"}, inplace=True)
        all_results[dataset] = pd.concat([all_results[dataset], xgb], axis=1)

# Concatenate all results
all_results = pd.concat([res for res in all_results.values()])
new = all_results.set_index(["Dataset"])
result = (
    new.groupby(["Dataset"]).mean().round(3).reset_index()
)
# add standard deviation per result to the table
for i in result.columns:
    if i != "Dataset":
        result[i] = result[i].astype(str) + "\u00B1" + new.groupby(["Dataset"]).std().round(3).reset_index()[i].astype(str)
result = result.set_index(["Dataset"])
# rename indices
result.rename(index={"Nmr": "NMR", "Full": "Clinical + NMR"}, inplace=True)
print(result)
result.to_latex(os.path.join(results_folder, "baselines_table.tex"), multirow=True, multicolumn=True, multicolumn_format="c", bold_rows=True, caption="Baseline models' performances on each dataset.", label="tab:baselines_res", float_format="%.2f")
all_results.fillna(0, inplace=True)

# %%
df_melted = all_results.melt(id_vars="Dataset", var_name="Model", value_name="Value")

fig, axes = plt.subplots(1, 3, sharey=True, figsize=(12, 6))

# get palette colors
palette = sns.color_palette("Set2", 3)
palette = {
    "Nmr": palette[2],
    "Clinical": palette[1],
    "Full": palette[0],
}
switch_name = {
    "Nmr": "NMR",
    "Clinical": "Clinical",
    "Full": "Clinical + NMR",

}
sns.set_theme(style="whitegrid")
for ax, dataset in zip(axes, ["Nmr", "Clinical", "Full"]):
    bp = sns.boxplot(
        data=df_melted[df_melted["Dataset"] == dataset],
        x="Model",
        y="Value",
        hue="Dataset",
        palette=palette,
        ax=ax,
        width=0.5,
    )
    ax.set_xlabel(switch_name[dataset])
    ax.set_ylabel("C-index")
    ax.set_ylim(0.5, 0.91)

# rotate x-tick labels
for ax in axes:
    ax.xaxis.set_tick_params(rotation=45)

# remove legends apart from last axis
for ax in axes:
    ax.legend([], [], frameon=False)

# despine, remove y-ticks & y-label on all but the first axis
sns.despine(ax=axes[0], trim=True, offset=10)
axes[0].grid(axis="y", linestyle="--", color="grey", alpha=0.7)
for ax in axes[1:]:
    sns.despine(ax=ax, left=True, trim=True, offset=10)
    ax.grid(axis="y", linestyle="--", color="grey", alpha=0.7)

# plt.legend(title="Dataset", loc="lower right", labels=["NMR", "Clinical", "Clinical + NMR"], handles=[plt.Line2D([0], [0], color=palette["Nmr"], lw=4), plt.Line2D([0], [0], color=palette["Clinical"], lw=4), plt.Line2D([0], [0], color=palette["Full"], lw=4)])
# Move clinical + NMR to the right
plt.tight_layout()
plt.savefig(os.path.join(results_folder, "boxplot_baselines_separate.pdf"))
plt.show()

# %%
import numpy as np
import os
from survival_dataset import SurvivalDataset
from visualization import (
    plot_survival_time,
    plot_survival_sd,
    plot_survival_calibration,
    plot_boxplots,
)

plot_path = "../results_models/xgb-aft/bagging2024-06-26_11-54-15"
for f in os.listdir(plot_path):
    if f.endswith(".npy"):
        if "test" not in f or "full" not in f:
            continue
        ys = np.load(os.path.join(plot_path, f))
        ds = f.split("_")[2].split(".npy")[0]
        dataset_test = SurvivalDataset()
        dataset_test.load_data(f"{ds}_test.csv")
        plot_survival_time(
            dataset_test,
            ys,
            interval=True,
            plot_path=plot_path if ds == "full" else None,
        )

        std_devs = ys.std(axis=0)
        ypred = ys.mean(axis=0)
        plot_survival_sd(
            dataset_test,
            ypred,
            std_devs,
            plot_path=plot_path if ds == "full" else None,
        )
        plot_survival_calibration(
            dataset_test,
            ys,
            plot_path=plot_path if ds == "full" else None,
        )
        plot_boxplots(plot_path)

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
all_results = {}
results_folder = "../results_models/xgb-aft/"

all_results = pd.DataFrame()
for f in os.listdir(results_folder):
    if "bagging" in f or "pdf" in f or "tex" in f:
        continue
    for f2 in os.listdir(os.path.join(results_folder, f)):
        if f2.endswith(".csv") and "test_results" in f2:
            dataset = f2.split(".csv")[0].split("test_results_")[-1].title()
            xgb = pd.read_csv(
                f"{results_folder}/{f}/{f2}"
            ).drop(columns=["Unnamed: 0"])[["C-index"]]
            exp_name = f.split("2024")[0]
            xgb.rename(columns={"C-index": f"{exp_name}-{dataset}"}, inplace=True)
            all_results = pd.concat([all_results, xgb], axis=1)
# split into three dataframes
nmr_df = all_results[[c for c in all_results.columns if "Nmr" in c]]
nmr_df.drop(columns=["without_gluc-Nmr", "only_gluc-Nmr"], inplace=True)

clinical_df = all_results[[c for c in all_results.columns if "Clinical" in c]]
clinical_df.rename(
    columns={
        "without_gluc-Clinical": "Excluding",
        "only_gluc-Clinical": "Uniquely",
        "normal-Clinical": "Including",
    },
    inplace=True,
)

full_df = all_results[[c for c in all_results.columns if "Full" in c]]
full_df.rename(
    columns={
        "without_gluc-Full": "Excluding",
        "only_gluc-Full": "Uniquely",
        "normal-Full": "Including",
    },
    inplace=True,
)

# %%
fig, axes = plt.subplots(1, 3, sharey=True, figsize=(12, 6))

# get palette colors
palette = sns.color_palette("Set2", 3)
switch_name = {
    "Nmr": "NMR",
    "Clinical": "Clinical",
    "Full": "Clinical + NMR",
}
sns.set_theme(style="whitegrid")
for ax, dataset in zip(axes, ["Nmr", "Clinical", "Full"]):
    if dataset == "Nmr":
        data = nmr_df
        color = palette[2]
    elif dataset == "Clinical":
        data = clinical_df
        color = palette[1]
    else:
        data = full_df
        color = palette[0]
    bp = sns.boxplot(
        data=data,
        color=color,
        ax=ax,
        width=0.5,
    )
    ax.set_xlabel(switch_name[dataset])
    ax.set_ylabel("C-index")
    ax.set_ylim(0.739, 0.89)
    ax.set_yticks(np.arange(0.74, 0.88, 0.02))
    if dataset == "Nmr":
        ax.set_xticklabels(["Including"])

# rotate x-tick labels
for ax in axes:
    ax.xaxis.set_tick_params(rotation=45)

# remove legends apart from last axis
for ax in axes:
    ax.legend([], [], frameon=False)

# despine, remove y-ticks & y-label on all but the first axis
sns.despine(ax=axes[0], trim=True, offset=10)
axes[0].grid(axis="y", linestyle="--", color="grey", alpha=0.7)
for ax in axes[1:]:
    sns.despine(ax=ax, left=True, trim=True, offset=10)
    ax.grid(axis="y", linestyle="--", color="grey", alpha=0.7)

# Move clinical + NMR to the right
plt.tight_layout()
plt.savefig(os.path.join(results_folder, "boxplot_gluc_compare.pdf"))
plt.show()

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
all_results = {}
results_folder = "../results_models/xgb-aft/"

all_results = pd.DataFrame()
for f in os.listdir(results_folder):
    if "bagging" in f or "pdf" in f or "tex" in f:
        continue
    for f2 in os.listdir(os.path.join(results_folder, f)):
        if f2.endswith(".csv") and "test_results" in f2:
            dataset = f2.split(".csv")[0].split("test_results_")[-1].title()
            xgb = pd.read_csv(f"{results_folder}/{f}/{f2}").drop(
                columns=["Unnamed: 0"]
            )
            exp_name = f.split("2024")[0]
            xgb.rename(columns={c: c + f"={exp_name}={dataset}" for c in xgb.columns}, inplace=True)
            all_results = pd.concat([all_results, xgb], axis=1)

# print(all_results)
# round to 3 decimals
df = all_results.round(3)

mean_df = df.mean().round(3)
std_df = df.std().round(3)

# Step 2: Create a dataframe with mean ± std
result_df = pd.DataFrame({"mean_std": mean_df.astype(str) + " ± " + std_df.astype(str)})

# Step 3: Restructure the dataframe
# Create a multi-index from the column names
result_df.index = pd.MultiIndex.from_tuples(
    [tuple(col.split("=")) for col in result_df.index]
)

result_df = result_df.unstack(level=1)

# Rename columns and reorder levels
result_df.columns = result_df.columns.droplevel(0)
result_df.rename(columns={"normal": "Including", "only_gluc": "Uniquely", "without_gluc": "Excluding"}, inplace=True)

result_df = result_df.swaplevel(0, 1, axis=0).T
# create multiindex for columns
result_df.columns = pd.MultiIndex.from_tuples(
    [col for col in result_df.columns], names=["Dataset", ""]
)
result_df.index.name = "Glucose"
result_df = result_df.sort_index(axis=1)

# %%
result_df.to_latex(
    os.path.join(results_folder, "glucose_table.tex"),
    multirow=True,
    multicolumn=True,
    multicolumn_format="c",
    bold_rows=True,
    caption="XGBoost AFT models' performances on each dataset with, without or only including glucose.",
    label="tab:glucose_res",
    float_format="%.2f",
)
